# %% [markdown]
# <a href="https://colab.research.google.com/github/ujeongmin/ESAA/blob/main/YB_9_15_%EA%B3%BC%EC%A0%9C%EB%AC%B8%EC%A0%9C_tips_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv',
                       sep = ',')
tips.head(5)
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips.drop('Unnamed: 0', axis=1, inplace=True)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
a = plt.subplots()
a = sns.distplot(tips['total_bill'], kde=False)                  # seaborn 라이브러리의 히스토그램 : sns.distplot()
a.set_title('Histogram of Total Bill')
a.set_xlabel('Total Bill')
a.set_ylabel('Frequency')
# Out:
# <ipython-input-42-dde88acea73a>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   a = sns.distplot(tips['total_bill'], kde=False)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
a = plt.subplots()
a = sns.regplot(x=tips['total_bill'], y=tips['tip'], fit_reg=False)                 # seaborn 라이브러리의 산점도 : sns.regplot()
a.set_title('Scatterplot of Total Bill & Tip')
a.set_xlabel('Total Bill')
a.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.pairplot(tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.stripplot(x='day', y='total_bill', data=tips)     # sns.stripplot : 범주형 데이터의 산점도 그리기
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.stripplot(x='tip', y='day', data=tips, hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
a = sns.FacetGrid(tips, col='time')             # time 별로 2개의 그래프 그림
a.map(plt.hist,'tip')                           # x축은 tip

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
a = sns.FacetGrid(tips, col='sex', hue='smoker')             # sex 별로 2개의 그래프 그림, smoker 여부로 점 색상 구분
a.map(plt.scatter,'total_bill','tip')                        # x축은 total_bill, y축은 tip
a.add_legend()                                               # smoker 여부에 따른 점 색상 뭔지 출력

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %% [markdown]
# sex에 따른 day별 total_bill의 box plot 만들기

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
